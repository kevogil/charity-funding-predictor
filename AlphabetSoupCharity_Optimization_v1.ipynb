# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
#  Import and read the charity_data.csv.
url = "https://raw.githubusercontent.com/kevogil/charity-funding-predictor/main/Resources/charity_data.csv"
application_df = pd.read_csv(url)

# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=['EIN', 'NAME', 'ORGANIZATION'], inplace=True)

# Look at APPLICATION_TYPE value counts for binning
app_cnt = application_df['APPLICATION_TYPE'].value_counts()

# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff_point = 500
application_types_to_replace = app_cnt[app_cnt < cutoff_point].index.tolist()


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Look at CLASSIFICATION value counts for binning
class_cnt = application_df['CLASSIFICATION'].value_counts()

# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_point = 1000
classifications_to_replace = class_cnt[class_cnt < cutoff_point].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Convert categorical data to numeric with `pd.get_dummies`
numeric_application_df = pd.get_dummies(application_df)

# Split our preprocessed data into our features and target arrays
y = numeric_application_df['IS_SUCCESSFUL']
x = numeric_application_df.drop(columns=['IS_SUCCESSFUL'])

# Split the preprocessed data into a training and testing dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42)

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
x_scaler = scaler.fit(x_train)

# Scale the data
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %%
### Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(x_train_scaled[0])
hidden_nodes_layer1 =  16
hidden_nodes_layer2 = 10
hidden_nodes_layer3 = 8

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 16)                640
#
#  dense_10 (Dense)            (None, 10)                170
#
#  dense_11 (Dense)            (None, 8)                 88
#
#  dense_12 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 907
# Trainable params: 907
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(x_train_scaled,y_train,epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6059 - accuracy: 0.6949
# Epoch 2/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5653 - accuracy: 0.7234
# Epoch 3/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5613 - accuracy: 0.7262
# Epoch 4/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5603 - accuracy: 0.7264
# Epoch 5/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5593 - accuracy: 0.7271
# Epoch 6/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5584 - accuracy: 0.7273
# Epoch 7/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5582 - accuracy: 0.7272
# Epoch 8/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5579 - accuracy: 0.7277
# Epoch 9/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5574 - accuracy: 0.7282
# Epoch 10/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5568 - accuracy: 0.7287
# Epoch 11/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5571 - accuracy: 0.7288
# Epoch 12/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5566 - accuracy: 0.7286
# Epoch 13/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5564 - accuracy: 0.7290
# Epoch 14/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5560 - accuracy: 0.7288
# Epoch 15/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5564 - accuracy: 0.7286
# Epoch 16/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5555 - accuracy: 0.7278
# Epoch 17/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5559 - accuracy: 0.7280
# Epoch 18/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5558 - accuracy: 0.7282
# Epoch 19/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5558 - accuracy: 0.7283
# Epoch 20/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5552 - accuracy: 0.7285
# Epoch 21/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5555 - accuracy: 0.7288
# Epoch 22/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5553 - accuracy: 0.7291
# Epoch 23/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5552 - accuracy: 0.7297
# Epoch 24/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5550 - accuracy: 0.7289
# Epoch 25/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5549 - accuracy: 0.7290
# Epoch 26/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5549 - accuracy: 0.7290
# Epoch 27/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5551 - accuracy: 0.7289
# Epoch 28/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5548 - accuracy: 0.7286
# Epoch 29/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5542 - accuracy: 0.7287
# Epoch 30/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5545 - accuracy: 0.7289
# Epoch 31/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5542 - accuracy: 0.7284
# Epoch 32/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5543 - accuracy: 0.7289
# Epoch 33/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5544 - accuracy: 0.7292
# Epoch 34/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5542 - accuracy: 0.7287
# Epoch 35/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5540 - accuracy: 0.7297
# Epoch 36/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5539 - accuracy: 0.7296
# Epoch 37/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5541 - accuracy: 0.7297
# Epoch 38/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5539 - accuracy: 0.7292
# Epoch 39/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5539 - accuracy: 0.7293
# Epoch 40/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5538 - accuracy: 0.7281
# Epoch 41/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5539 - accuracy: 0.7303
# Epoch 42/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5538 - accuracy: 0.7302
# Epoch 43/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.7299
# Epoch 44/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5535 - accuracy: 0.7297
# Epoch 45/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.7292
# Epoch 46/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5535 - accuracy: 0.7293
# Epoch 47/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5533 - accuracy: 0.7298
# Epoch 48/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5535 - accuracy: 0.7301
# Epoch 49/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5533 - accuracy: 0.7294
# Epoch 50/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5535 - accuracy: 0.7303
# Epoch 51/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.7297
# Epoch 52/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5531 - accuracy: 0.7296
# Epoch 53/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5530 - accuracy: 0.7296
# Epoch 54/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5531 - accuracy: 0.7291
# Epoch 55/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5529 - accuracy: 0.7301
# Epoch 56/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5528 - accuracy: 0.7300
# Epoch 57/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5530 - accuracy: 0.7303
# Epoch 58/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5526 - accuracy: 0.7302
# Epoch 59/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5524 - accuracy: 0.7302
# Epoch 60/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5526 - accuracy: 0.7301
# Epoch 61/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5524 - accuracy: 0.7299
# Epoch 62/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5525 - accuracy: 0.7305
# Epoch 63/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5524 - accuracy: 0.7304
# Epoch 64/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5525 - accuracy: 0.7296
# Epoch 65/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5525 - accuracy: 0.7303
# Epoch 66/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5521 - accuracy: 0.7294
# Epoch 67/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5523 - accuracy: 0.7302
# Epoch 68/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5525 - accuracy: 0.7299
# Epoch 69/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5522 - accuracy: 0.7302
# Epoch 70/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5520 - accuracy: 0.7299
# Epoch 71/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5521 - accuracy: 0.7297
# Epoch 72/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5521 - accuracy: 0.7305
# Epoch 73/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5520 - accuracy: 0.7304
# Epoch 74/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5518 - accuracy: 0.7300
# Epoch 75/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5521 - accuracy: 0.7301
# Epoch 76/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7299
# Epoch 77/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5517 - accuracy: 0.7304
# Epoch 78/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7299
# Epoch 79/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5520 - accuracy: 0.7302
# Epoch 80/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5518 - accuracy: 0.7302
# Epoch 81/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5517 - accuracy: 0.7308
# Epoch 82/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5520 - accuracy: 0.7303
# Epoch 83/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7310
# Epoch 84/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7304
# Epoch 85/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5518 - accuracy: 0.7302
# Epoch 86/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7292
# Epoch 87/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7304
# Epoch 88/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5513 - accuracy: 0.7295
# Epoch 89/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5518 - accuracy: 0.7308
# Epoch 90/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5515 - accuracy: 0.7307
# Epoch 91/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7300
# Epoch 92/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5515 - accuracy: 0.7300
# Epoch 93/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7308
# Epoch 94/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5513 - accuracy: 0.7302
# Epoch 95/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7306
# Epoch 96/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7305
# Epoch 97/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7305
# Epoch 98/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7304
# Epoch 99/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7301
# Epoch 100/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7306
# Epoch 101/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7308
# Epoch 102/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7303
# Epoch 103/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7310
# Epoch 104/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7304
# Epoch 105/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7314
# Epoch 106/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7310
# Epoch 107/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7307
# Epoch 108/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5505 - accuracy: 0.7316
# Epoch 109/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7312
# Epoch 110/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7311
# Epoch 111/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7304
# Epoch 112/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5511 - accuracy: 0.7301
# Epoch 113/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7308
# Epoch 114/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7309
# Epoch 115/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7308
# Epoch 116/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7312
# Epoch 117/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7301
# Epoch 118/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7310
# Epoch 119/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7311
# Epoch 120/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7308
# Epoch 121/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7318
# Epoch 122/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7308
# Epoch 123/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7308
# Epoch 124/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7317
# Epoch 125/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7295
# Epoch 126/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7309
# Epoch 127/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7314
# Epoch 128/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5507 - accuracy: 0.7313
# Epoch 129/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7313
# Epoch 130/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7318
# Epoch 131/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7313
# Epoch 132/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7311
# Epoch 133/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7308
# Epoch 134/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7315
# Epoch 135/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5507 - accuracy: 0.7315
# Epoch 136/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7316
# Epoch 137/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7311
# Epoch 138/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7312
# Epoch 139/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7317
# Epoch 140/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7311
# Epoch 141/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7308
# Epoch 142/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5504 - accuracy: 0.7315
# Epoch 143/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7305
# Epoch 144/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7314
# Epoch 145/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7318
# Epoch 146/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5505 - accuracy: 0.7319
# Epoch 147/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5504 - accuracy: 0.7314
# Epoch 148/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7312
# Epoch 149/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7308
# Epoch 150/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7318
# Epoch 151/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5503 - accuracy: 0.7311
# Epoch 152/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7312
# Epoch 153/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5505 - accuracy: 0.7319
# Epoch 154/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7320
# Epoch 155/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5505 - accuracy: 0.7311
# Epoch 156/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5500 - accuracy: 0.7318
# Epoch 157/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5505 - accuracy: 0.7302
# Epoch 158/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7318
# Epoch 159/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7315
# Epoch 160/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7321
# Epoch 161/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5505 - accuracy: 0.7315
# Epoch 162/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7311
# Epoch 163/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7314
# Epoch 164/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5502 - accuracy: 0.7317
# Epoch 165/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7312
# Epoch 166/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7309
# Epoch 167/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7315
# Epoch 168/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7322
# Epoch 169/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5503 - accuracy: 0.7315
# Epoch 170/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7319
# Epoch 171/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7315
# Epoch 172/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5505 - accuracy: 0.7312
# Epoch 173/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7315
# Epoch 174/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7313
# Epoch 175/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7311
# Epoch 176/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7314
# Epoch 177/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5502 - accuracy: 0.7315
# Epoch 178/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7315
# Epoch 179/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7318
# Epoch 180/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7320
# Epoch 181/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5500 - accuracy: 0.7321
# Epoch 182/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5500 - accuracy: 0.7319
# Epoch 183/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7323
# Epoch 184/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7317
# Epoch 185/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7311
# Epoch 186/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7312
# Epoch 187/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7316
# Epoch 188/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7318
# Epoch 189/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7311
# Epoch 190/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7322
# Epoch 191/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7314
# Epoch 192/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7323
# Epoch 193/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7319
# Epoch 194/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7316
# Epoch 195/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7314
# Epoch 196/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7313
# Epoch 197/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5500 - accuracy: 0.7315
# Epoch 198/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7317
# Epoch 199/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7317
# Epoch 200/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7317

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5690 - accuracy: 0.7251 - 409ms/epoch - 2ms/step
# Loss: 0.569019079208374, Accuracy: 0.7251312136650085

# %%
# Save and export your results to an HDF5 file
from google.colab import files

nn.save('AlphabetSoupCharity_Optimization_v1.h5')
files.download('AlphabetSoupCharity_Optimization_v1.h5')
